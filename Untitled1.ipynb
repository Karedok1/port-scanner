# %%
import socket
import threading
from datetime import datetime



print("="*33)
print("    SIMPLE PORT SCANNER")
print("="*33)

ip_input = input(("masukan alamat ip (pisahkan dengan koma): "))
ip_list = [ip.strip() for ip in ip_input.split(",")]
print(f"ip list {ip_list}")





awal = int(input("masukan port: "))
akhir = int(input("masukan port: "))
thread_list = []
pertama = datetime.now()


def scan_port(ip, port):
    try:
        service = socket.getservbyport(port)

    except Exception:
        service = "unknown"
        pass



    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(0.7)
    result = s.connect_ex((ip, port))
    if result == 0:
        print(f"{ip} port {port} terbuka {service.upper()}")

    else:
        print(f"{ip} tertutup {port}")
    s.close()


for ip in ip_list:
    for port in range(awal, akhir + 1):
        thread = threading.Thread(target=scan_port, args=(ip, port))
        thread.start()
        thread_list.append(thread)

for t in thread_list:
    t.join()


selesai = datetime.now()
i = selesai - pertama
print(i)
# Out:
# ...
#     SIMPLE PORT SCANNER
# ...
# masukan alamat ip (pisahkan dengan koma): 203.0.113.1, 203.0.113.2, 203.0.113.3
# ip list ['203.0.113.1', '203.0.113.2', '203.0.113.3']
# masukan port: 90
# masukan port: 100
# 203.0.113.1 tertutup 91203.0.113.1 tertutup 92
# 203.0.113.1 tertutup 90
# 203.0.113.1 tertutup 95
# 203.0.113.1 tertutup 94
# 203.0.113.1 tertutup 98
# 203.0.113.1 tertutup 96
# 203.0.113.1 tertutup 100
# 203.0.113.1 tertutup 93
# 203.0.113.1 tertutup 97
# 203.0.113.1 tertutup 99
#
# 203.0.113.2 tertutup 91
# 203.0.113.2 tertutup 94
# 203.0.113.2 tertutup 90
# 203.0.113.2 tertutup 93
# 203.0.113.2 tertutup 92
# 203.0.113.2 tertutup 98
# 203.0.113.2 tertutup 95
# 203.0.113.2 tertutup 97
# 203.0.113.2 tertutup 96
# 203.0.113.2 tertutup 99
# 203.0.113.2 tertutup 100
# 203.0.113.3 tertutup 90
# 203.0.113.3 tertutup 93
# 203.0.113.3 tertutup 95
# 203.0.113.3 tertutup 91
# 203.0.113.3 tertutup 94
# 203.0.113.3 tertutup 92
# 203.0.113.3 tertutup 96
# 203.0.113.3 tertutup 98
# ...

# %% [markdown]
# To use the Gemini API, you'll need an API key. If you don't already have one, create a key in Google AI Studio.
# In Colab, add the key to the secrets manager under the "🔑" in the left panel. Give it the name `GOOGLE_API_KEY`. Then pass the key to the SDK:
